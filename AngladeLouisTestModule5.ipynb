# %%
def add(a, b):
    return a + b

# %%
import unittest
from calculator import add

class TestCalculator(unittest.TestCase):
    def test_add(self):
        self.assertEqual(add(2, 3), 5)

# %%
When I ran the unit test in VS Code, the test runner executed the test function inside my TestCalculator class. The test compared the expected output of my function to the actual output.

If the function returned the correct value, the test showed a green checkmark, meaning the code behaved as expected.

If the function returned the wrong value, the test would show a failure, meaning the code did not produce the expected result.

The test results tell me whether my function is working correctly. A passing test means the function's behavior matches what I intended. A failing test means I need to fix the code or adjust the logic. Unit tests help confirm that each part of my program works the way it should.
