# %%
# %%writefile zoo.py
def hours():
    print('Open 9-5 daily')
# Out:
# Overwriting zoo.py

# %%
with open("zoo.py", "w") as f:
    f.write("""def hours():
    print('Open 9-5 daily')
""")

# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily
